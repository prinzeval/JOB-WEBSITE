# %%
from time import sleep 
from selenium import webdriver 
import pandas as pd
from bs4 import BeautifulSoup 
import requests 
chrome_driver_path = r'C:\Users\ELITEBOOK 1030\Downloads\chromedriver-win64\chromedriver.exe'
import html5lib

# %%
r=requests.get("https://www.indeed.com/jobs?q=data+engineer&l=New+York%2C+NY&vjk=af1c846c34ac0534")
r.status_code
# Out:
# 403

# %% [markdown]
# INDEED JOBS SCRAPING (LOADS OF CODES) LOL

# %%
main_link= 'https://www.indeed.com/jobs?q=data+analyst+entry+level&l=Remote&vjk=eb304b6d79a1ae31'     # indeed main url 

# Initialize WebDriver
driver = webdriver.Chrome(chrome_driver_path)
driver.get(main_link)
sleep(10)

indeed_cards = driver.find_elements_by_xpath(
    '//div[@class="job_seen_beacon"]')
print(indeed_cards)

my_card_link_list=[]
indeed_card_list=[]
sleep(7)
heads = "https://www.indeed.com"

sleep(7)
for WebElement in indeed_cards:
    sleep(5)
    elementHTML = WebElement.get_attribute('outerHTML')
    sleep(5)
    elementsoup = BeautifulSoup(elementHTML, 'html5lib')
    sleep(6)
    card_link= elementsoup.find('a',href = True)
    card_join = (card_link['href'])
    my_card_link = heads + card_join
    my_card_link_list.append(my_card_link)
print(my_card_link_list)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f2409603d7f0895b340bda04574b6f79", element="f.094E230F4B6168B7321ADC2A8AF360A0.d.D4B63C5228A5F927215FE5B0C8BF8FA2.e.73")>, <selenium.webdriver.remote.webelement.WebElement (session="f2409603d7f0895b340bda04574b6f79", element="f.094E230F4B6168B7321ADC2A8AF360A0.d.D4B63C5228A5F927215FE5B0C8BF8FA2.e.74")>, <selenium.webdriver.remote.webelement.WebElement (session="f2409603d7f0895b340bda04574b6f79", element="f.094E230F4B6168B7321ADC2A8AF360A0.d.D4B63C5228A5F927215FE5B0C8BF8FA2.e.75")>, <selenium.webdriver.remote.webelement.WebElement (session="f2409603d7f0895b340bda04574b6f79", element="f.094E230F4B6168B7321ADC2A8AF360A0.d.D4B63C5228A5F927215FE5B0C8BF8FA2.e.76")>, <selenium.webdriver.remote.webelement.WebElement (session="f2409603d7f0895b340bda04574b6f79", element="f.094E230F4B6168B7321ADC2A8AF360A0.d.D4B63C5228A5F927215FE5B0C8BF8FA2.e.77")>, <selenium.webdriver.remote.webelement.WebElement (session="f2409603d7f0895b340bda04574b6f79", element="f.094E230F4B6168B7321ADC2A8AF360A0.d.D4B63C5228A5F927215FE5B0C8BF8FA2.e.78")>, <selenium.webdriver.remote.webelement.WebElement (session="f2409603d7f0895b340bda04574b6f79", element="f.094E230F4B6168B7321ADC2A8AF360A0.d.D4B63C5228A5F927215FE5B0C8BF8FA2.e.79")>, <selenium.webdriver.remote.webelement.WebElement (session="f2409603d7f0895b340bda04574b6f79", element="f.094E230F4B6168B7321ADC2A8AF360A0.d.D4B63C5228A5F927215FE5B0C8BF8FA2.e.80")>, <selenium.webdriver.remote.webelement.WebElement (session="f2409603d7f0895b340bda04574b6f79", element="f.094E230F4B6168B7321ADC2A8AF360A0.d.D4B63C5228A5F927215FE5B0C8BF8FA2.e.81")>, <selenium.webdriver.remote.webelement.WebElement (session="f2409603d7f0895b340bda04574b6f79", element="f.094E230F4B6168B7321ADC2A8AF360A0.d.D4B63C5228A5F927215FE5B0C8BF8FA2.e.82")>, <selenium.webdriver.remote.webelement.WebElement (session="f2409603d7f0895b340bda04574b6f79", element="f.094E230F4B6168B7321ADC2A8AF360A0.d.D4B63C5228A5F927215FE5B0C8BF8FA2.e.83")>, <selenium.webdriver.remote.webelement.WebElement (session="f2409603d7f0895b340bda04574b6f79", element="f.094E230F4B6168B7321ADC2A8AF360A0.d.D4B63C5228A5F927215FE5B0C8BF8FA2.e.84")>, <selenium.webdriver.remote.webelement.WebElement (session="f2409603d7f0895b340bda04574b6f79", element="f.094E230F4B6168B7321ADC2A8AF360A0.d.D4B63C5228A5F927215FE5B0C8BF8FA2.e.85")>, <selenium.webdriver.remote.webelement.WebElement (session="f2409603d7f0895b340bda04574b6f79", element="f.094E230F4B6168B7321ADC2A8AF360A0.d.D4B63C5228A5F927215FE5B0C8BF8FA2.e.86")>, <selenium.webdriver.remote.webelement.WebElement (session="f2409603d7f0895b340bda04574b6f79", element="f.094E230F4B6168B7321ADC2A8AF360A0.d.D4B63C5228A5F927215FE5B0C8BF8FA2.e.87")>]
# ['https://www.indeed.com/rc/clk?jk=e824d7327afeae95&bb=VG4OmRR4551giNegUSaUiYMTrlhrAlUOPRRVR_e7OMZ7wtrWrlUNCA8RkVc0vdExjvrrKjBM7GkoLqFvjlKWqtfQOYru1fQPD82kzEGpExi6TB9ACfmgNA%3D%3D&xkcb=SoBh67M3CPGhggw8MZ0LbzkdCdPP&fccid=544af407da89bfb9&vjs=3', 'https://www.indeed.com/rc/clk?jk=27dd5b9d28cd3fef&bb=VG4OmRR4551giNegUSaUiZN2N4UqaATnYnVZmnF4dpYIGC0_B_jijLjHG101A9Fs-cGslhK8f4CuOVITvx75qWuO7IM2nk-7tFSqLrvxODYI8HXVlFuq9g%3D%3D&xkcb=SoDV67M3CPGhggw8MZ0KbzkdCdPP&fccid=c74820549fd8456b&vjs=3', 'https://www.indeed.com/rc/clk?jk=7bdb09239409f0a4&bb=VG4OmRR4551giNegUSaUiTumCW7I3lEL1UcCmM4n9R6rsKDq3LjJSLYeqPHmMfsEV9pDETbzqcSn205qtPGvvtNKiip_AyWZwNXFpnR8kbyMnXSr9rvdSA%3D%3D&xkcb=SoBI67M3CPGhggw8MZ0JbzkdCdPP&fccid=aa1951fc953bbe56&vjs=3', 'https://www.indeed.com/rc/clk?jk=8f8ddee2f1766dd4&bb=VG4OmRR4551giNegUSaUiZxNszw8LX4PfNZLxhL5SsJ6fe4wMkF7doqYjTg-7wO6DUQnAtb9PYcooSXeCYLh1T3JaQExq8fWegM7Mu8S-WC5zh7YSY4vzg%3D%3D&xkcb=SoD867M3CPGhggw8MZ0IbzkdCdPP&fccid=94d16cd43a57a0d8&vjs=3', 'https://www.indeed.com/rc/clk?jk=f1b0d4398653bacf&bb=VG4OmRR4551giNegUSaUiZxNszw8LX4PT8kC_UPbU5RW2-yice8aUAwUqX_9ow_WkSDnVFQG9ZWZ4Wpejcr9MPAqvspp64PHTdwH7FqGQDXL1PXCt2RsCA%3D%3D&xkcb=SoBy67M3CPGhggw8MZ0PbzkdCdPP&fccid=59c7b888afaec443&vjs=3', 'https://www.indeed.com/rc/clk?jk=ce2acd6c0fb73d51&bb=VG4OmRR4551giNegUSaUiebK-blZ6IWiVXX7CWJ21JZzXasWpyGMLDEgraxiW99BxO6D5p_bh8NH5CylNR_sCnhltnyc54weZ1wjJi0b76A%3D&xkcb=SoDG67M3CPGhggw8MZ0ObzkdCdPP&fccid=81ddb723255b4ba2&vjs=3', 'https://www.indeed.com/rc/clk?jk=dfe5e07bb4e2bf1c&bb=VG4OmRR4551giNegUSaUiWoffZyo6XhsK1MndPY7YNkzuJ5NmzAzGy6d0EIlCY4ff1blx3axpT1_cU31EBUACsngT-MPyRzCltSiSN4LLaYEfd606D_G8A%3D%3D&xkcb=SoBb67M3CPGhggw8MZ0NbzkdCdPP&fccid=19a18eb8591e2da7&vjs=3', 'https://www.indeed.com/rc/clk?jk=46ba35ead9e2a561&bb=VG4OmRR4551giNegUSaUiST_VGcwRqWNN16-Y3SrhcC7ug2srEQAB3eq1iTfI5O8WkEP1pIlYFrXWtr78NxFgwbS9cOn3oyfwk5qbmBem0M%3D&xkcb=SoDv67M3CPGhggw8MZ0MbzkdCdPP&fccid=e290923a98afee94&vjs=3', 'https://www.indeed.com/rc/clk?jk=4677882769bacb8f&bb=VG4OmRR4551giNegUSaUiTumCW7I3lEL6_H6LFta-v_dqCNq4TD-noEoZdpnOlLq5i3_hxgvbZylQDhY492GhXN2zK7fyRiLO0mtjlreIduY_MyI7Vvz-w%3D%3D&xkcb=SoAG67M3CPGhggw8MZ0DbzkdCdPP&fccid=15c26b2f7c7309c1&vjs=3', 'https://www.indeed.com/rc/clk?jk=fe1eae94ec61be5e&bb=VG4OmRR4551giNegUSaUibTjT6zs6Oggv7Ng7l853fvl_e4RzfPy79rCvKevTyGYyz_fDnIjHEShk7opViMe5kvl8MSsj6jEyJ5RJDK0AqFpjuec2-9xYg%3D%3D&xkcb=SoCy67M3CPGhggw8MZ0CbzkdCdPP&fccid=d844fa152b5f8ad2&vjs=3', 'https://www.indeed.com/rc/clk?jk=7ee106f47e7a876d&bb=VG4OmRR4551giNegUSaUiVlEsHtEhkwO_G-ANnRSErITBYFe4Q-ZY3BjGEjeDMMzjWhttOsOiLJi5LJBtED32lx1OcH23yngBtUSB8ZptyIgkOKA-G8FHg%3D%3D&xkcb=SoAv67M3CPGhggw8MZ0BbzkdCdPP&fccid=3d652a9c3ad19024&vjs=3', 'https://www.indeed.com/rc/clk?jk=59bd344a6bc2a8bb&bb=VG4OmRR4551giNegUSaUiao_Sg0uMsEnJ4N2deDaw_9UEWJLIE0OQGbpXPrt19Ds_uNvw4C-LsdA-Iu9P8qj2x0NcQyIdxyTXZdTWfdNqZw6RcB4oNDJgA%3D%3D&xkcb=SoCb67M3CPGhggw8MZ0AbzkdCdPP&fccid=e5f741bf43df9079&vjs=3', 'https://www.indeed.com/rc/clk?jk=17ca7075b6f52a8c&bb=VG4OmRR4551giNegUSaUiUFMtCm_4xC03CYpCHJZaZVwIjQYqW5U4AuaNmYBBApeXjiVHKB_TppaClcC9HXOQAZFqa29t3nQsoHbm1NmKOHCt5CF1KMK5g%3D%3D&xkcb=SoAV67M3CPGhggw8MZ0HbzkdCdPP&fccid=e24a60f01d1882d1&vjs=3', 'https://www.indeed.com/rc/clk?jk=96f36bc0f484008f&bb=VG4OmRR4551giNegUSaUiW0vGZNF0jgDWxKuxVElr2394gfsOSeGsBI3uQQV4PPHTzYknIAVRPBk9RrEzf2KMSLuz3qEq7J9CmQezROnEGA%3D&xkcb=SoCh67M3CPGhggw8MZ0GbzkdCdPP&fccid=11caadcdc98800d4&vjs=3', 'https://www.indeed.com/rc/clk?jk=958669264aa4f2f9&bb=VG4OmRR4551giNegUSaUiTqgaKzpguzSd-XhpPelFwbcliAz9_Bb1vNasQPFleppshdTH_gfUtQs9tdYgeYCvBRGlzdwBGkUL_ADtWuVJ5BoHFUIK8PPqQ%3D%3D&xkcb=SoA867M3CPGhggw8MZ0FbzkdCdPP&fccid=5acf3c1d84f9b6de&vjs=3']

# %%
position_list = []
company_name_list = []
location_list = []
salary_list = []
job_link_list = []
benefit_list = []
description_list  = []
employment_type_list= []


for lines in my_card_link_list:
    driver.get(lines)
    sleep(2)
    html_content = driver.page_source
    sharksoup = BeautifulSoup(html_content, 'html.parser')
    
    # Position
    linkz = sharksoup.find('div', {'class': 'jobsearch-InfoHeaderContainer jobsearch-DesktopStickyContainer css-zt53js eu4oa1w0'})
    position = linkz.find('h1').text.strip() if linkz and linkz.find('h1') else "NULL"
    position_list.append(position)

    # Company Name
    company_name = linkz.find('span', {'class': "css-1saizt3 e1wnkr790"}).text.strip() if linkz and linkz.find('span', {'class': "css-1saizt3 e1wnkr790"}) else "NULL"
    company_name_list.append(company_name)

    # Location
    location = linkz.find('div', {'class': "css-1ikmi61 eu4oa1w0"}).text.strip() if linkz and linkz.find('div', {'class': "css-1ikmi61 eu4oa1w0"}) else "NULL"
    location_list.append(location)

    # Salary
    salary = linkz.find('span', {'class': "css-19j1a75 eu4oa1w0"})
    salary_text = salary.text.strip() if salary else "NULL"
    salary_list.append(salary_text)

    # Job Link
    # Apply_link =sharksoup.find('div', {'class': "jobsearch-ViewJobButtons-container css-15enpd4 eu4oa1w0 jobsearch-DesktopStickyContainer-buttonscontainer"})
    # button = Apply_link.find('button', class_='css-1oxck4n e8ju0x51')
    # if button:
    #     job_link = button['href']
    #     job_link_list.append(job_link)

    Apply_link = sharksoup.find('div', {'class': "jobsearch-ViewJobButtons-container css-15enpd4 eu4oa1w0 jobsearch-DesktopStickyContainer-buttonscontainer"})
    button = Apply_link.find('button', class_='css-1oxck4n e8ju0x51')
    job_link = button['href']
    job_link_list.append(job_link)    

    #Employment Type
    employment = sharksoup.find('div', {'class': "js-match-insights-provider-xu0md5 eu4oa1w0"})
    employ = employment.find('div', {'class': "js-match-insights-provider-tvvxwd ecydgvn1"}).text.strip() if employment and employment.find('div', {'class': "js-match-insights-provider-tvvxwd ecydgvn1"}) else "NULL"
    employment_type_list.append(employ)



    # Benefits
    benefit = sharksoup.find('div', {'id': "benefits", 'data-testid': "benefits-test", 'class': "css-jaxxzt eu4oa1w0"})
    benefits_list = []
    if benefit:
        ul_element = benefit.find('ul', {'class': 'css-8tnble eu4oa1w0'})
        if ul_element:
                benefits_list = [li_element.text.strip() for li_element in ul_element.find_all('li')]
    benefit_list.append(benefits_list if benefits_list else "No benefits found.")

    # Description
    description = sharksoup.find('div', {'id': "jobDescriptionText", 'class': "jobsearch-jobDescriptionText jobsearch-JobComponent-description css-10og78z eu4oa1w0"}).text.strip()
    description_list.append(description if description else "NULL")

print(position_list)
print(company_name_list) 
print(location_list) 
print(salary_list) 
print(job_link_list) 
print(benefit_list) 
print(description_list) 
print(employment_type_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 43
#      35 # Job Link
#      36 # Apply_link =sharksoup.find('div', {'class': "jobsearch-ViewJobButtons-container css-15enpd4 eu4oa1w0 jobsearch-DesktopStickyContainer-buttonscontainer"})
#      37 # button = Apply_link.find('button', class_='css-1oxck4n e8ju0x51')
#      38 # if button:
#      39 #     job_link = button['href']
#      40 #     job_link_list.append(job_link)
#      42 Apply_link = sharksoup.find('div', {'class': "jobsearch-ViewJobButtons-container css-15enpd4 eu4oa1w0 jobsearch-DesktopStickyContainer-buttonscontainer"})
# ---> 43 button = Apply_link.find('button', class_='css-1oxck4n e8ju0x51')
#      44 job_link = button['href']
#      45 job_link_list.append(job_link)
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
TABLE = {'POSITION':position_list,'COMPANY NAME': company_name_list,"LOCATION":location_list,'SALARY':salary_list,"JOB LINK":job_link_list,"BENEFITS":benefit_list,'DESCRIPTION':description_list,'EMPLOYMENT TYPE':employment_type_list}
daf = pd.DataFrame(TABLE)
daf
# Out:
#                                  POSITION  \
# 0                    Senior Data Engineer
# 1                       Data Engineer III
# 2                           Data Engineer
# 3                           Data Engineer
# 4           Data Engineer, Trust & Safety
# 5                           Data Engineer
# 6                    Senior Data Engineer
# 7               Senior Data Engineer- AWS
# 8                           Data Engineer
# 9                    Senior Data Engineer
# 10                       Sr Data Engineer
# 11              Data Integration Engineer
# 12                   Senior Data Engineer
# 13  Data Engineer, Amazon Shopping Videos
# 14                          Data Engineer
#
#                               COMPANY NAME  \
# 0   Disney Entertainment & ESPN Technology
# 1                              Match Group
# 2                            Paul Hastings
# 3                          Beyond Identity
# 4                                     Meta
# 5                       NYPD Civilian Jobs
# 6                               CVS Health
# 7                         Publicis Sapient
# 8                          Lord Abbett.com
# 9                                 MEDIDATA
# 10                         Cardinal Health
# 11                               Riskified
# 12                              Keyrus USA
# 13                 Amazon.com Services LLC
# 14                              Tek Ninjas
#
#                                    LOCATION                      SALARY  \
# 0                              New York, NY  $136,038 - $182,490 a year
# 1                              New York, NY  $143,000 - $172,000 a year
# 2                        New York, NY 10017       Up to $162,500 a year
# 3                              New York, NY  $155,000 - $180,000 a year
# 4                              New York, NY  $134,000 - $204,000 a year
# 5                             Manhattan, NY              $71,920 a year
# 6                              New York, NY   $97,335 - $201,900 a year
# 7         375 Hudson St, New York, NY 10014  $103,000 - $154,000 a year
# 8   90 Hudson Street, Jersey City, NJ 07302  $100,000 - $110,000 a year
# 9                              New York, NY  $114,750 - $153,000 a year
# 10                             New York, NY  $119,800 - $171,100 a year
# 11          220 5th Ave, New York, NY 10001  $110,000 - $130,000 a year
# 12        252 W 37th St, New York, NY 10018  $120,000 - $140,000 a year
# 13                             New York, NY        From $105,700 a year
# 14                        Hoboken, NJ 07030                        NULL
#
#                                              JOB LINK  \
# 0   https://www.indeed.com/applystart?jk=afece6001...
# 1   https://www.indeed.com/applystart?jk=9ac908fea...
# 2   https://www.indeed.com/applystart?jk=9f936e2bb...
# 3   https://www.indeed.com/applystart?jk=b30e975fd...
# 4   https://www.indeed.com/applystart?jk=29ba329e0...
# 5   https://www.indeed.com/applystart?jk=9562c51b7...
# 6   https://www.indeed.com/applystart?jk=6335f8b82...
# 7   https://www.indeed.com/applystart?jk=9cc2e5122...
# 8   https://www.indeed.com/applystart?jk=3d92f3277...
# 9   https://www.indeed.com/applystart?jk=b688863d5...
# 10  https://www.indeed.com/applystart?jk=0b888a980...
# 11  https://www.indeed.com/applystart?jk=c1a498e6b...
# 12  https://www.indeed.com/applystart?jk=e3caf5184...
# 13  https://www.indeed.com/applystart?jk=5a999c911...
# 14  https://www.indeed.com/applystart?jk=4148618af...
#
#                                              BENEFITS  \
# 0                                  [Health insurance]
# 1   [401(k), 401(k) matching, Paid parental leave,...
# 2   [401(k), AD&D insurance, Commuter assistance, ...
# 3   [401(k), Dental insurance, Health insurance, P...
# 4                                  No benefits found.
# 5                                  [Loan forgiveness]
# 6   [401(k), Dental insurance, Disability insuranc...
# 7             [Parental leave, Tuition reimbursement]
# 8                 [Health insurance, Retirement plan]
# 9   [401(k), 401(k) matching, Dental insurance, Di...
# 10  [401(k), Dental insurance, Disability insuranc...
# 11  [401(k), 401(k) matching, Commuter assistance,...
# 12                                 No benefits found.
# 13                                 [Health insurance]
# 14                                 No benefits found.
#
#                                           DESCRIPTION EMPLOYMENT TYPE
# 0   On any given day at Disney Entertainment & ESP...            NULL
# 1   Hinge is the dating app designed to be deleted...            NULL
# 2   Paul Hastings is a leading international law f...            NULL
# 3   The Opportunity\n As a Data Engineer at Beyond...            NULL
# 4   Every month, billions of people leverage Meta ...            NULL
# 5   DISTRICT ATTORNEY-MANHATTAN \n\n\n\n\n\n\nFull...            NULL
# 6   Bring your heart to CVS Health. Every one of u...            NULL
# 7   Publicis Sapient is looking for a Senior Assoc...            NULL
# 8   The Role: \n  Lord Abbett is looking for a tal...            NULL
# 9   Medidata: Powering Smarter Treatments and Heal...            NULL
# 10  Job Description\n\n What Data Engineering cont...            NULL
# 11  About Us\n Riskified (NYSE: RSKD) empowers bus...            NULL
# 12  WHO WE ARE:\n Keyrus Group is a trusted leader...            NULL
# 13  3+ years of data engineering experience\nExper...            NULL
# 14  Needs: PYTHON SPARK  Nice to Haves: Tableau GC...            NULL

# %%
import pandas as pd


file_path = r'C:\Users\ELITEBOOK 1030\OneDrive\Desktop\my website\DAY 7\limited.csv\output.csv'

# Save the DataFrame to a CSV file
daf.to_csv(file_path, index=False)  

print("DataFrame successfully saved to CSV file.")
# Out:
# DataFrame successfully saved to CSV file.

# %%
import re

# Sample text containing job description, responsibilities, and other sections
text = "Paul Hastings is a leading international law firm that provides innovative legal solutions to many of the world's top financial institutions and Fortune Global 500 companies. With a strong presence throughout Asia, Europe, Latin America, and the U.S., we have the global reach and extensive capabilities to provide personalized service wherever our clients’ needs take us. As one of the world’s leading law firms, we seek dynamic individuals who share our commitment to service, innovation, and professional growth. We have an opening for a Data Engineer. The Data Engineer is responsible for expanding and optimizing our data and data pipeline architecture, as well as optimizing data flow and collection. The Data Engineer is an experienced data pipeline builder who enjoys optimizing data systems and building them from the ground up. This individual will support our software developers, architects, and data owners across various data initiatives and ensures an optimal and consistent data delivery architecture. They must be self-directed and comfortable supporting the data needs of multiple teams, systems and products. In this capacity, the Data Engineer will: Design, construct, test and maintain data architectures and data pipelines; Ensure our data architecture supports the requirements of the business; Develop custom data models and algorithms to apply to data sets; Assess the effectiveness and accuracy of new data sources and data gathering techniques. Discover opportunities for data acquisition; Develop data set processes for data modeling, mining and production; Employ a variety of languages and tools to marry systems together; Recommend ways to improve data reliability, efficiency and quality; Leverage large volumes of data from internal and external sources to answer business demands; Introduce automation through effective metadata management and using innovative and modern tools and techniques. Partially or completely automate the most common and repeatable data preparation and integration tasks; Propose appropriate data ingestion, preparation, integration and operationalization techniques in addressing data requirements; Lead the development of data governance policies and best practices for consumers and users of data we provision; Coordinate with different functional teams to implement models and monitor outcomes; and Develop processes and tools to monitor and analyze model performance and data accuracy. Proficiencies: Demonstrates knowledge of the following processes, tools or applications; Experienced in designing, building and managing data pipelines for data structures; Expertise with advanced analytics tools for Object-oriented/object function scripting. Includes languages such as C#, Python and others Expert in SQL, PL/SQL, SSIS and SSAS; Knowledge and/or certifications on upcoming NoSQL/Hadoop-oriented databases like MongoDB, Cassandra, and others for non-relational databases; Experienced working with large, heterogeneous data sets in building and optimizing data pipelines, pipeline architectures and integrated datasets using traditional data integration technologies; Experienced working with popular data discovery, analytics and BI software tools such as Tableau, Power BI and others; Experienced working with data governance/data quality and data security teams; Experienced employing Microsoft MDM (Master Data Management) and MDS; Ability to troubleshoot complicated issues across multiple systems and driving solutions; Effectively convey technical concepts to non-technical individuals; Demonstrate a high level of Data Security Awareness; and Experience with financial and legal industry data is a plus. Qualifications: A Bachelor's or Master's degree in computer science, statistics, applied mathematics, data management, information systems, information science or a related quantitative field or equivalent work experience; At least five years’ experience in data management disciplines including data integration, modeling, optimization and data quality, and/or other areas directly relevant to data engineering responsibilities and tasks; At least three years’ experience working in cross-functional teams and collaborating with business stakeholders in support of a departmental and/or multi-departmental data management and analytics initiative; Excellent communication and collaboration skills; Excellent problem solving and analytical skills; Must be highly effective within a collaborative environment; and Must be able to independently resolve issues and efficiently self-direct work activities based on the ability to capture, organize, and analyze information. Employees will be provided with an excellent career opportunity in a collaborative environment, in addition to a generous total compensation package with the opportunity to earn bonuses based on individual contribution and firm profitability. The salary wage range that we expect to pay for this position is a minimum of $112,300 and a maximum of $162,500 annually. The actual pay wage may vary based on experience or other relevant factors. Eligible employees can participate in the Firm’s comprehensive benefits program, which include the following: Medical, Dental, Vision, Life/AD&D, Long Term Care, and Short and Long Term Disability Flexible Spending Account and Health Savings Account Healthcare Concierge and Advocacy Voluntary 401k Plan and Profit Sharing 10 Paid Holidays per year and a generous PTO program Family Support including Pediatric Mental Health and Parental Support, Paid Parental Leave, Fertility Benefits, and Breast Milk Shipping Back-up Child Care, Elder Care, and Tutoring Wellness Programs (Employee Assistance Program, Mental Health, and Well-Being Events) Retirement Plan Consulting Anniversary Bonus Program Professional Development Programs Transportation Allowance and Commuter Benefits International Travel Insurance Auto/Home/Legal Insurance Pet Insurance Employee discounts And more! The Firm has a range of diversity initiatives including our Paul Hastings Affinity Networks (PHANs), Women’s Initiative, and PH Balanced. These initiatives provide a firmwide forum to share experiences, as well as an opportunity to participate in a supportive network with common interests to help make life at the firm more inclusive. Learn more about our Global Diversity, Inclusion and Wellness Initiatives here. Paul Hastings LLP is an equal employment and affirmative action employer F/M/Disability/Vet/Sexual Orientation/Gender Identity."

# Define regular expressions to match patterns for each section
description_pattern = re.compile(r'Description:(.*?)(?:Responsibilities:|Qualifications:|$)', re.DOTALL)
responsibilities_pattern = re.compile(r'Responsibilities:(.*?)(?:Qualifications:|$)', re.DOTALL)
other_sections_pattern = re.compile(r'Qualifications:(.*?)$', re.DOTALL)

# Extract text for each section using regular expressions
description_match = description_pattern.search(text)
responsibilities_match = responsibilities_pattern.search(text)
other_sections_match = other_sections_pattern.search(text)

# Print the separated sections
description = description_match.group(1).strip() if description_match else ""
responsibilities = responsibilities_match.group(1).strip() if responsibilities_match else ""
other_sections = other_sections_match.group(1).strip() if other_sections_match else ""

print("Description:", description)
print("Responsibilities:", responsibilities)
print("Other Sections:", other_sections)
# Out:
# Description:
# Responsibilities:
# Other Sections: A Bachelor's or Master's degree in computer science, statistics, applied mathematics, data management, information systems, information science or a related quantitative field or equivalent work experience; At least five years’ experience in data management disciplines including data integration, modeling, optimization and data quality, and/or other areas directly relevant to data engineering responsibilities and tasks; At least three years’ experience working in cross-functional teams and collaborating with business stakeholders in support of a departmental and/or multi-departmental data management and analytics initiative; Excellent communication and collaboration skills; Excellent problem solving and analytical skills; Must be highly effective within a collaborative environment; and Must be able to independently resolve issues and efficiently self-direct work activities based on the ability to capture, organize, and analyze information. Employees will be provided with an excellent career opportunity in a collaborative environment, in addition to a generous total compensation package with the opportunity to earn bonuses based on individual contribution and firm profitability. The salary wage range that we expect to pay for this position is a minimum of $112,300 and a maximum of $162,500 annually. The actual pay wage may vary based on experience or other relevant factors. Eligible employees can participate in the Firm’s comprehensive benefits program, which include the following: Medical, Dental, Vision, Life/AD&D, Long Term Care, and Short and Long Term Disability Flexible Spending Account and Health Savings Account Healthcare Concierge and Advocacy Voluntary 401k Plan and Profit Sharing 10 Paid Holidays per year and a generous PTO program Family Support including Pediatric Mental Health and Parental Support, Paid Parental Leave, Fertility Benefits, and Breast Milk Shipping Back-up Child Care, Elder Care, and Tutoring Wellness Programs (Employee Assistance Program, Mental Health, and Well-Being Events) Retirement Plan Consulting Anniversary Bonus Program Professional Development Programs Transportation Allowance and Commuter Benefits International Travel Insurance Auto/Home/Legal Insurance Pet Insurance Employee discounts And more! The Firm has a range of diversity initiatives including our Paul Hastings Affinity Networks (PHANs), Women’s Initiative, and PH Balanced. These initiatives provide a firmwide forum to share experiences, as well as an opportunity to participate in a supportive network with common interests to help make life at the firm more inclusive. Learn more about our Global Diversity, Inclusion and Wellness Initiatives here. Paul Hastings LLP is an equal employment and affirmative action employer F/M/Disability/Vet/Sexual Orientation/Gender Identity.

# %%
import csv
import pymysql

# MySQL database connection details
HOST = 'localhost'
USER = 'root'
PASSWORD = 'Vondabaic2020'
DATABASE = 'val_data'

# Function to establish MySQL connection
def connect_to_database():
    try:
        connection = pymysql.connect(
            host=HOST,
            user=USER,
            password=PASSWORD,
            database=DATABASE,
            cursorclass=pymysql.cursors.DictCursor
        )
        return connection
    except pymysql.Error as e:
        print(f"Error connecting to MySQL database: {e}")
        return None

# Function to read CSV file and insert data into database
def insert_data_from_csv(csv_file):
    try:
        # Establish connection to MySQL database
        connection = connect_to_database()
        if connection is None:
            return

        # Open CSV file and create CSV reader object
        with open(csv_file, 'r', newline='', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            
            # Iterate over each row in the CSV file
            for row in reader:
                # Truncate job_link value if it exceeds maximum length
                job_link = row['JOB LINK'][:255]  # Assuming the maximum length is 255 characters

                # Prepare INSERT statement
                insert_query = """
                    INSERT INTO job_postings (position, company_name, location, salary, job_link, benefits, description, employment_type)
                    VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
                """
                values = (
                    row['POSITION'],
                    row['COMPANY NAME'],
                    row['LOCATION'],
                    row['SALARY'],
                    job_link,  # Use truncated job_link value
                    row['BENEFITS'],
                    row['DESCRIPTION'],
                    row['EMPLOYMENT TYPE']
                )

                # Execute INSERT statement
                with connection.cursor() as cursor:
                    cursor.execute(insert_query, values)

        # Commit changes to the database
        connection.commit()
        print("Data inserted successfully!")

    except Exception as e:
        print(f"Error inserting data into database: {e}")

    finally:
        # Close database connection
        if connection:
            connection.close()

# Path to your CSV file
csv_file_path = 'C:/Users/ELITEBOOK 1030/OneDrive/Desktop/output.csv'

# Call function to insert data from CSV into database
insert_data_from_csv(csv_file_path)
# Out:
# Data inserted successfully!
