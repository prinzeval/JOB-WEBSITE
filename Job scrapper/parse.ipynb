# %% [markdown]
# INDEED JOBS SCRAPING (LOADS OF CODES) LOL

# %%
from time import sleep
from selenium.webdriver.common.by import By
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time

# Prompt user for job title and location
job_title = input("Enter the job title you're looking for (e.g., 'data analyst entry level'): ")
location = input("Enter the job location (e.g., 'Remote' or 'New York'): ")

# Format the inputs for URL query
formatted_job_title = job_title.replace(' ', '+')
formatted_location = location.replace(' ', '+')

# Construct Indeed search URL based on user input
main_link = f'https://www.indeed.com/jobs?q={formatted_job_title}&l={formatted_location}'

# Initialize WebDriver
driver = webdriver.Chrome()  # Make sure ChromeDriver is properly set up
driver.get(main_link)
sleep(2)

# Find job cards
indeed_cards = driver.find_elements(By.XPATH, '//div[@class="job_seen_beacon"]')
print(indeed_cards)

# Initialize lists for storing job details
my_card_link_list = []
heads = "https://www.indeed.com"

# Extract job links
for WebElement in indeed_cards:
    sleep(3)
    elementHTML = WebElement.get_attribute('outerHTML')
    elementsoup = BeautifulSoup(elementHTML, 'html5lib')
    card_link = elementsoup.find('a', href=True)
    if card_link:
        card_join = card_link['href']
        my_card_link = heads + card_join
        my_card_link_list.append(my_card_link)

print("Job Links:", my_card_link_list)

# Close the driver
driver.quit()

from time import sleep
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time
from bs4 import BeautifulSoup

driver = webdriver.Chrome() 

# Lists to store extracted data
position_list = []
company_name_list = []
location_list = []
salary_list = []
var_job_link_list = []
benefit_list = []
description_list = []
employment_type_list = []

# Loop through each job link
for lines in my_card_link_list:
    driver.get(lines)
    sleep(2)
    html_content = driver.page_source
    sharksoup = BeautifulSoup(html_content, 'html.parser')
    
    # Position
    linkz = sharksoup.find('div', {'class': 'jobsearch-InfoHeaderContainer jobsearch-DesktopStickyContainer css-zt53js eu4oa1w0'})
    position = linkz.find('h1').text.strip() if linkz and linkz.find('h1') else "NULL"
    position_list.append(position)

    # Company Name
    company_name_element = linkz.find('span', {'class': "css-1saizt3 e1wnkr790"})
    company_name = company_name_element.text.strip() if company_name_element else "NULL"
    company_name_list.append(company_name)

    # Location
    location = "NULL"  # Initialize with default value

    location_1 = linkz.find('div', {'class': "css-waniwe eu4oa1w0"}).text.strip() if linkz and linkz.find('div', {'class': "css-waniwe eu4oa1w0"}) else "NULL"
    location_2 = linkz.find('div', {'class': "css-17cdm7w eu4oa1w0"}).text.strip() if linkz and linkz.find('div', {'class': "css-17cdm7w eu4oa1w0"}) else "NULL"
    # Determine final location based on the logic
    if location_1 != "NULL" and location_2 != "NULL":
        location = f"{location_1}, {location_2}"  # Both locations found
    elif location_1 != "NULL":
        location = location_1  # Only the first location found
    elif location_2 != "NULL":
        location = location_2  # Only the second location found
    
    location_list.append(location)  # Append the final location value

    # Salary
    salary = linkz.find('span', {'class': "css-19j1a75 eu4oa1w0"})
    salary_text = salary.text.strip() if salary else "NULL"
    salary_list.append(salary_text)

    # Job Link (Updated logic to get the link)
    apply_link_container = sharksoup.find('div', {'id': 'viewJobButtonLinkContainer', 'class': 'icl-u-lg-inlineBlock viewJobButtonLinkContainer css-aunbg2 eu4oa1w0'})
    job_link = None

    if apply_link_container:
        # Find the button tag within the container
        button_tag = apply_link_container.find('button', class_='css-1oxck4n e8ju0x51')
        # Extract the 'href' attribute (custom attribute in this case)
        job_link = button_tag.get('href') if button_tag else "No job link found"
        var_job_link_list.append(job_link)

    # Employment Type
    employment = sharksoup.find('div', {'class': 'css-1xkrvql eu4oa1w0'})
    employ = employment.find('span', {'class': "css-k5flys eu4oa1w0"}).text.strip() if employment and employment.find('span', {'class': "css-k5flys eu4oa1w0"}) else "NULL"
    employment_type_list.append(employ)

    # Benefits
    benefit = sharksoup.find('div', {'id': "benefits", 'data-testid': "benefits-test", 'class': "css-eynugf eu4oa1w0"})  
    benefits_list = []
    if benefit:
        ul_element = benefit.find('ul', {'class': 'css-8tnble eu4oa1w0'})
        if ul_element:
            benefits_list = [li_element.text.strip() for li_element in ul_element.find_all('li')]
    benefit_list.append(benefits_list if benefits_list else "No benefits found.")

    # Description
    description_div = sharksoup.find('div', {'id': "jobDescriptionText", 'class': "jobsearch-JobComponent-description css-16y4thd eu4oa1w0"})
    description = description_div.text.strip() if description_div else "NULL"
    description_list.append(description)

Job_link_list = []

# Configure ChromeDriver
options = Options()
options.add_argument("--headless")
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.199 Safari/537.36")

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# Process job links
for job_link in var_job_link_list:
    try:
        driver.get(job_link)

        # Wait for the redirection to complete
        WebDriverWait(driver, 20).until(
            EC.url_changes(job_link)
        )
        time.sleep(1)  # Additional buffer time

        # Capture redirected URL
        redirected_url = driver.current_url
        Job_link_list.append(redirected_url)
        
    except Exception as e:
        print(f"Error processing {job_link}: {e}")

# Close the browser
driver.quit()

# Output lists
print("Position List:", position_list)
print("Company Name List:", company_name_list)
print("Location List:", location_list)
print("Salary List:", salary_list)
print("Job Link List:", Job_link_list)
print("Benefit List:", benefit_list)
print("Description List:", description_list)
print("Employment Type List:", employment_type_list)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="584a621b596f1a93ffb086f0f48b6309", element="f.4B5089EA73F3C9F26EAB8BA19E08C932.d.990AEF7B69C76E205B1BD0698550C843.e.68")>, <selenium.webdriver.remote.webelement.WebElement (session="584a621b596f1a93ffb086f0f48b6309", element="f.4B5089EA73F3C9F26EAB8BA19E08C932.d.990AEF7B69C76E205B1BD0698550C843.e.69")>, <selenium.webdriver.remote.webelement.WebElement (session="584a621b596f1a93ffb086f0f48b6309", element="f.4B5089EA73F3C9F26EAB8BA19E08C932.d.990AEF7B69C76E205B1BD0698550C843.e.70")>, <selenium.webdriver.remote.webelement.WebElement (session="584a621b596f1a93ffb086f0f48b6309", element="f.4B5089EA73F3C9F26EAB8BA19E08C932.d.990AEF7B69C76E205B1BD0698550C843.e.71")>, <selenium.webdriver.remote.webelement.WebElement (session="584a621b596f1a93ffb086f0f48b6309", element="f.4B5089EA73F3C9F26EAB8BA19E08C932.d.990AEF7B69C76E205B1BD0698550C843.e.72")>, <selenium.webdriver.remote.webelement.WebElement (session="584a621b596f1a93ffb086f0f48b6309", element="f.4B5089EA73F3C9F26EAB8BA19E08C932.d.990AEF7B69C76E205B1BD0698550C843.e.73")>, <selenium.webdriver.remote.webelement.WebElement (session="584a621b596f1a93ffb086f0f48b6309", element="f.4B5089EA73F3C9F26EAB8BA19E08C932.d.990AEF7B69C76E205B1BD0698550C843.e.74")>, <selenium.webdriver.remote.webelement.WebElement (session="584a621b596f1a93ffb086f0f48b6309", element="f.4B5089EA73F3C9F26EAB8BA19E08C932.d.990AEF7B69C76E205B1BD0698550C843.e.75")>, <selenium.webdriver.remote.webelement.WebElement (session="584a621b596f1a93ffb086f0f48b6309", element="f.4B5089EA73F3C9F26EAB8BA19E08C932.d.990AEF7B69C76E205B1BD0698550C843.e.76")>, <selenium.webdriver.remote.webelement.WebElement (session="584a621b596f1a93ffb086f0f48b6309", element="f.4B5089EA73F3C9F26EAB8BA19E08C932.d.990AEF7B69C76E205B1BD0698550C843.e.77")>, <selenium.webdriver.remote.webelement.WebElement (session="584a621b596f1a93ffb086f0f48b6309", element="f.4B5089EA73F3C9F26EAB8BA19E08C932.d.990AEF7B69C76E205B1BD0698550C843.e.78")>, <selenium.webdriver.remote.webelement.WebElement (session="584a621b596f1a93ffb086f0f48b6309", element="f.4B5089EA73F3C9F26EAB8BA19E08C932.d.990AEF7B69C76E205B1BD0698550C843.e.79")>, <selenium.webdriver.remote.webelement.WebElement (session="584a621b596f1a93ffb086f0f48b6309", element="f.4B5089EA73F3C9F26EAB8BA19E08C932.d.990AEF7B69C76E205B1BD0698550C843.e.80")>, <selenium.webdriver.remote.webelement.WebElement (session="584a621b596f1a93ffb086f0f48b6309", element="f.4B5089EA73F3C9F26EAB8BA19E08C932.d.990AEF7B69C76E205B1BD0698550C843.e.81")>, <selenium.webdriver.remote.webelement.WebElement (session="584a621b596f1a93ffb086f0f48b6309", element="f.4B5089EA73F3C9F26EAB8BA19E08C932.d.990AEF7B69C76E205B1BD0698550C843.e.82")>]
# Job Links: ['https://www.indeed.com/rc/clk?jk=ec7ca7b916dcf862&bb=p1oxohcSK5sP13uqVcsEXkDAkwFAiUampRUXr7LqB7XtUKpHDAIG5pV_Wd8VCXjvlDpgnPOsKfG1qdf0vNLh2vArpHHyDkYf7kUKN1lQyIFPu92AecliRmgXCN3iENaD&xkcb=SoB867M358qbVFQHYx0LbzkdCdPP&fccid=5822a2554404d85f&vjs=3', 'https://www.indeed.com/rc/clk?jk=bee305d4e68e63d9&bb=p1oxohcSK5sP13uqVcsEXjVkopfE1IDEASFjPBiFwPVk11DQfLyjEmGqqzF5JL3kLE6oi9mp5bJv30ahhgj1BxQLNFzKBrM381lOZ0HtrVL-vnpEDqacWrK-hmZ5TEN-&xkcb=SoDI67M358qbVFQHYx0KbzkdCdPP&fccid=82e3f19d796cce5c&vjs=3',
remote', 'Remote', 'Remote', 'Remote', 'Remote', 'Remote', 'Remote', 'Remote', 'Remote', 'Remote', 'Remote', 'Remote', 'Remote', 'Remote', 'Remote']
# Salary List: ['NULL', 'NULL', 'NULL', '$92,352 - $95,000 a year', '$40,000 - $50,000 a year', '$75,000 - $78,000 a year', 'From $75,000 a year', '$64,300 - $94,500 a year', 'NULL', 'NULL', '$62,400 - $129,600 a year', 'NULL', 'NULL', '$95,000 - $155,000 a year', '$49,000 - $65,000 a year']
# Job Link List: ['https://careers.firstsource.com/job/Remote-Data-Entry-Remo/32170044/?src=Indeed', 'https://equitable.taleo.net/careersection/eqh_1/jobdetail.ftl?job=21000104&tz=GMT-06%3A00&tzname=America%2FChicago', 'https://jobs.ascension.org/us/en/job/AHEAHUUS372529EXTERNALENUS/Data-Analyst?phenom_utm_medium=phenom-feeds&utm_source=appcast_indeed&utm_medium=organic&utm_campaign=USASC_AllJobs&iisn=Appcast_Indeed&iis=Organic&iisc=USASC_AllJobs&iieid=58373072984&_ccid=1732903239168n3np9aete&ittk=4ZIAZKDGXW', 'https://careers-personifyhealth.icims.com/jobs/3704/job?utm_source=indeed_integration&iis=Job+Board&iisn=Indeed&indeed-apply-token=73a2d2b2a8d6d5c0a62696875eaebd669103652d3f0c2cd5445d3e66b1592b0f', 'https://volarisgroup.wd3.myworkdayjobs.com/en-US/WynneNA/job/Remote-United-States/Service-Desk-Analyst---Level-1_R54448?utm_source=Indeed&utm_medium=organic&utm_campaign=Indeed', 'https://onedigital.wd5.myworkdayjobs.com/en-US/OneDigital/job/Remote/Data-Analyst---Remote_R6564', 'https://doane.peopleadmin.com/postings/2028', 'https://www.stitchfix.com/careers/jobs?gh_jid=6371275', 'https://intone.com/careers-at-intone/', 'https://cansofttech.com/careers/', 'https://akamaicareers.inflightcloud.com/jobdetails/aka_ext/035937?section=aka_ext&src=JB-10122&job=035937', 'https://lakeappliancerepair.com/now-hiring-data-analyst/', 'https://jobs.navient.com/job/-/-/3354/73620362832?utm_campaign=fy17&utm_medium=job_board&utm_content=paid_search&utm_source=indeed.com', 'https://crowdstrike.wd5.myworkdayjobs.com/en-US/crowdstrikecareers/job/USA---Remote/Data-Warehouse-Analyst---Governance-and-Security--Remote-_R21077?indeed_organic', 'https://wexinc.wd5.myworkdayjobs.com/en-US/WEXInc/job/US---Remote/Financial-Crimes-QA-Analyst_R16676?src=JB-10060']
# Benefit List: ['No benefits found.', ['401(k) matching', 'Dental insurance', 'Disability insurance', 'Employee stock purchase plan', 'Health insurance', 'Life insurance', 'Vision insurance'], ['Adoption assistance', 'Disability insurance', 'Employee assistance program', 'Health insurance', 'Paid time off', 'Parental leave', 'Retirement plan'], 'No benefits found.', 'No benefits found.', ['Health insurance', 'Paid time off'], ['Paid time off'], ['Dental insurance', 'Health insurance', 'Vision insurance'], 'No benefits found.', ['Opportunities for advancement'], ['401(k)', 'Employee assistance program', 'Employee stock purchase plan', 'Health insurance', 'Paid time off', 'Parental leave'], ['Paid holidays', 'Paid sick time', 'Paid time off', 'Retirement plan'], 'No benefits found.', ['Health insurance', 'Paid parental leave', 'Parental leave'], ['Dental insurance', 'Disability insurance', 'Flexible spending account', 'Health insurance', 'Health savings account', 'Life insurance', 'Paid time off']]
# Description List: ['Date: Nov 22, 2024\n      \n\n\n\n\n\n\n\n       Location: Remote, Remote, US\n      \n\n\n\n\n\n\n\n       Requisition ID: 12835\n      \n\n\n\n\n\n\n\n       Description: \n       The Data Entry Operator is an entry level position which is production oriented. Individuals are responsible for the introduction of data into the system which is then provided to the client for use in their internal adjudication system.\n\nFOUNDATION KNOWLEDGE, SKILLS, AND/OR ABILITIES REQUIRED\nTo perform this job successfully, an individual must be able to perform each essential duty satisfactorily. The requirements listed below are representative of the knowledge, skill, and/or ability required. Reasonable accommodations may be made to enable individuals with disabilities to perform the essential functions\nESSENTIAL DUTIES AND RESPONSIBLITIES •\nEnter data from scanned and/or processed images into the data capture system.\nMeet expected hourly production volume goals.\nMaintain quality levels above minimums set by management\nIncrease speed and difficulty of tasks as expected with training and practice\n\nADDITIONAL RESPONSIBILITIES\n\nMaintain awareness of and actively participate in the Corporate Compliance Program.\n\n\nMaintain a neat and orderly workstation.\n\n\nAssist with other projects as assigned by management\n\n\nMust be prompt and dependable (excellent attendance)\n\n\nMust be comfortable working in a production environment\n\n\nProficient typing skills are required (35wpm / 98% accuracy min) (test required).\n\n\nPossess excellent organization skills\n\n\nReliability of task completion and follow-up\n\nQualifications - External\nEDUCATION/PREVIOUS EXPERIENCE\nHigh School diploma or equivalent\nExcellent Data Entry Skills\nComputer Knowledge\nBasic Math Skill', 'Entry Level – Wealth Management Associate - NJ, Secaucus (4045) (21000104)\n \n\n Primary Location : UNITED STATES-Remote\n \n\n Organization : Equitable Advisors\n \n\n Description\n\n Equitable Advisors is a respected wealth management firm with a proven track record in the industry. We are driven by our mission to help our clients secure their financial well-being providing them confidence to pursue long and fulfilling lives. We have a passion to make a positive impact on the futures of individuals and businesses by offering financial services and products that address their evolving financial needs throughout their lifetime.\n Our people\nOur Financial Professionals come from a variety of backgrounds including recent college grads, career crossovers and experienced financial professionals, yet they all share several key traits: demonstrated patterns of success, values driven, entrepreneurial mindset, knack for networking and possess a desire to shape and protect their future as well as those they serve.\n\nWe value and respect people of all backgrounds and focus on developing diverse talent and fostering an inclusive work environment\n\n\nOur Diversity, Equity, and Inclusion (DEI) initiatives thrive from opportunities to participate in activities such as employee resource groups to our much-anticipated celebration of cultures and accomplishments at the annual Diversity Summit\n\n\nSocial impact and community engagement prosper thru our programs such as “1,000 Hours of Giving Back” sponsored by our Women’s Network and “Equitable Excellence” providing 200 college scholarships annually\n\n\nEnjoy the flexibility for Work Life Balance enabling us to identify with our authentic selves\n\n\n\n\n\n\n Qualifications\n\n\n Training and support\n\nTo get started as a Financial Professional, Equitable Advisors will sponsor your pursuit of the FINRA licensing requirements as well as help you navigate state licensing needs.\n\nOur entry level training curriculum is designed to empower you with the skills and tools needed for success: client relationship management, product knowledge, market development, role play and access to a full suite of remote-work technol ...
dPP&fccid=7b49ca0064093e91&vjs=3', 'https://www.indeed.com/rc/clk?jk=bee305d4e68e63d9&bb=SOfVZhZpg5Nz21sFeBcaP1xsQsanoh-VQQwtdtKYruD4hYWVSYkQDBKf5Na4LAET3ouA4Iew4N09NmYdvZNTwlwqbLW2sfHvHhjYUIGQDYup8mBUXREYAb0A7ViM5e7l&xkcb=SoA167M358XY5AgCJr0FbzkdCdPP&fccid=82e3f19d796cce5c&vjs=3']

# %%
TABLE = {'POSITION':position_list,'COMPANY NAME': company_name_list,"LOCATION":location_list,'SALARY':salary_list,"JOB LINK":Job_link_list,"BENEFITS":benefit_list,'DESCRIPTION':description_list,'EMPLOYMENT TYPE':employment_type_list}
daf = pd.DataFrame(TABLE)
daf
# Out:
#                                              POSITION            COMPANY NAME  \
# 0                                          Data Entry  Firstsource Healthcare
# 1           Entry Level – Wealth Management Associate      Equitable Advisors
# 2                                        Data Analyst               Ascension
# 3                                    Data Engineer II        Personify Health
# 4                      Service Desk Analyst - Level 1            Wynne System
# 5                               Data Analyst - Remote              OneDigital
# 6                            Strategic Data Analyst I        Doane University
# 7                           Planning Analyst, Women's              Stitch Fix
# 8                              Mid-level Data Analyst         Intone Networks
# 9                              Human Resource Analyst             CANSofttech
# 10             Strategy & Operations Analyst - Remote                  Akamai
# 11                                       Data Analyst   Lake Appliance Repair
# 12                                Reporting Associate                 NAVIENT
# 13  Data Warehouse Analyst - Governance and Securi...             CrowdStrike
# 14                        Financial Crimes QA Analyst                WEX Inc.
#
#    LOCATION                     SALARY  \
# 0    Remote                       NULL
# 1    Remote                       NULL
# 2    Remote                       NULL
# 3    Remote   $92,352 - $95,000 a year
# 4    Remote   $40,000 - $50,000 a year
# 5    Remote   $75,000 - $78,000 a year
# 6    Remote        From $75,000 a year
# 7    Remote   $64,300 - $94,500 a year
# 8    Remote                       NULL
# 9    Remote                       NULL
# 10   Remote  $62,400 - $129,600 a year
# 11   Remote                       NULL
# 12   Remote                       NULL
# 13   Remote  $95,000 - $155,000 a year
# 14   Remote   $49,000 - $65,000 a year
#
#                                              JOB LINK  \
# 0   https://careers.firstsource.com/job/Remote-Dat...
# 1   https://equitable.taleo.net/careersection/eqh_...
# 2   https://jobs.ascension.org/us/en/job/AHEAHUUS3...
# 3   https://careers-personifyhealth.icims.com/jobs...
# 4   https://volarisgroup.wd3.myworkdayjobs.com/en-...
# 5   https://onedigital.wd5.myworkdayjobs.com/en-US...
# 6         https://doane.peopleadmin.com/postings/2028
# 7   https://www.stitchfix.com/careers/jobs?gh_jid=...
# 8               https://intone.com/careers-at-intone/
# 9                    https://cansofttech.com/careers/
# 10  https://akamaicareers.inflightcloud.com/jobdet...
# 11  https://lakeappliancerepair.com/now-hiring-dat...
# 12  https://jobs.navient.com/job/-/-/3354/73620362...
# 13  https://crowdstrike.wd5.myworkdayjobs.com/en-U...
# 14  https://wexinc.wd5.myworkdayjobs.com/en-US/WEX...
#
#                                              BENEFITS  \
# 0                                  No benefits found.
# 1   [401(k) matching, Dental insurance, Disability...
# 2   [Adoption assistance, Disability insurance, Em...
# 3                                  No benefits found.
# 4                                  No benefits found.
# 5                   [Health insurance, Paid time off]
# 6                                     [Paid time off]
# 7   [Dental insurance, Health insurance, Vision in...
# 8                                  No benefits found.
# 9                     [Opportunities for advancement]
# 10  [401(k), Employee assistance program, Employee...
# 11  [Paid holidays, Paid sick time, Paid time off,...
# 12                                 No benefits found.
# 13  [Health insurance, Paid parental leave, Parent...
# 14  [Dental insurance, Disability insurance, Flexi...
#
#                                           DESCRIPTION EMPLOYMENT TYPE
# 0   Date: Nov 22, 2024\n      \n\n\n\n\n\n\n\n    ...            NULL
# 1   Entry Level – Wealth Management Associate - NJ...            NULL
# 2   Details \n\nDepartment: Network Services\n Sch...       Full-time
# 3   Overview: \n \n Now is the time to join us!\n\...    -  Full-time
# 4   Build Your Career and Future at Wynne.\n \n\n\...    -  Full-time
# 5   Are you looking to accelerate your career with...    -  Full-time
# 6   Position Title\n\n\n      Strategic Data Analy...    -  Full-time
# 7   About Stitch Fix, Inc. \nStitch Fix (NASDAQ: S...            NULL
# 8   Title: Mid-level Data Analyst Loaction:(Remote...        Contract
# 9   CANSofttech offers you more than just a job. W...            NULL
# 10  Do you like collaborating across teams to deli...            NULL
# 11  Lake Appliance Repair is seeking an experience...       Full-time
# 12  At Navient, we deliver technology-enabled fina...       Full-time
# 13  #WeAreCrowdStrike and our mission is to stop b...    -  Full-time
# 14  How you will make an impact:\n \n\nResponsible...    -  Full-time

# %%
import pandas as pd

# Make sure your DataFrame creation logic is above this part
# For example:
TABLE = {
    'POSITION': position_list,
    'COMPANY NAME': company_name_list,
    'LOCATION': location_list,
    'SALARY': salary_list,
    'JOB LINK': Job_link_list,
    'BENEFITS': benefit_list,
    'DESCRIPTION': description_list,
    'EMPLOYMENT TYPE': employment_type_list
}
daf = pd.DataFrame(TABLE)

# Specify the file path
file_path = r'C:\Users\valen\Desktop\JOB-WEBSITE\output.csv'

# Save the DataFrame to a CSV file
daf.to_csv(file_path, index=False)

print("DataFrame successfully saved to CSV file.")
# Out:
# DataFrame successfully saved to CSV file.

# %%
pip install supabase
# Out:
# Collecting supabase
#   Using cached supabase-2.10.0-py3-none-any.whl.metadata (10 kB)
# Collecting gotrue<3.0.0,>=2.10.0 (from supabase)
#   Downloading gotrue-2.11.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting httpx<0.28,>=0.26 (from supabase)
#   Using cached httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting postgrest<0.19,>=0.18 (from supabase)
#   Using cached postgrest-0.18.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting realtime<3.0.0,>=2.0.0 (from supabase)
#   Using cached realtime-2.0.6-py3-none-any.whl.metadata (6.7 kB)
# Collecting storage3<0.10.0,>=0.9.0 (from supabase)
#   Using cached storage3-0.9.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting supafunc<0.8.0,>=0.7.0 (from supabase)
#   Using cached supafunc-0.7.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pydantic<3,>=1.10 (from gotrue<3.0.0,>=2.10.0->supabase)
#   Downloading pydantic-2.10.2-py3-none-any.whl.metadata (170 kB)
# Collecting anyio (from httpx<0.28,>=0.26->supabase)
#   Using cached anyio-4.6.2.post1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi in c:\users\valen\desktop\job-website\.venv\lib\site-packages (from httpx<0.28,>=0.26->supabase) (2024.8.30)
# Collecting httpcore==1.* (from httpx<0.28,>=0.26->supabase)
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in c:\users\valen\desktop\job-website\.venv\lib\site-packages (from httpx<0.28,>=0.26->supabase) (3.10)
# Requirement already satisfied: sniffio in c:\users\valen\desktop\job-website\.venv\lib\site-packages (from httpx<0.28,>=0.26->supabase) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\valen\desktop\job-website\.venv\lib\site-packages (from httpcore==1.*->httpx<0.28,>=0.26->supabase) (0.14.0)
# Collecting deprecation<3.0.0,>=2.1.0 (from postgrest<0.19,>=0.18->supabase)
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting aiohttp<4.0.0,>=3.10.10 (from realtime<3.0.0,>=2.0.0->supabase)
#   Downloading aiohttp-3.11.8-cp312-cp312-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.1 in c:\users\valen\desktop\job-website\.venv\lib\site-packages (from realtime<3.0.0,>=2.0.0->supabase) (2.9.0.post0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.12.2 in c:\users\valen\desktop\job-website\.venv\lib\site-packages (from realtime<3.0.0,>=2.0.0->supabase) (4.12.2)
# Collecting websockets<14,>=11 (from realtime<3.0.0,>=2.0.0->supabase)
#   Using cached websockets-13.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.10.10->realtime<3.0.0,>=2.0.0->supabase)
#   Using cached aiohappyeyeballs-2.4.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.10.10->realtime<3.0.0,>=2.0.0->supabase)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\valen\desktop\job-website\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.10.10->realtime<3.0.0,>=2.0.0->supabase) (24.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.10.10->realtime<3.0.0,>=2.0.0->supabase)
#   Using cached frozenlist-1.5.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.10.10->realtime<3.0.0,>=2.0.0->supabase)
#   Using cached multidict-6.1.0-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.10.10->realtime<3.0.0,>=2.0.0->supabase)
#   Using cached propcache-0.2.0-cp312-cp312-win_amd64.whl.metadata (7.9 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.10.10->realtime<3.0.0,>=2.0.0->supabase)
#   Downloading yarl-1.18.0-cp312-cp312-win_amd64.whl.metadata (69 kB)
# Requirement already satisfied: packaging in c:\users\valen\desktop\job-website\.venv\lib\site-packages (from deprecation<3.0.0,>=2.1.0->postgrest<0.19,>=0.18->supabase) (24.2)
# Collecting h2<5,>=3 (from httpx[http2]<0.28,>=0.26->gotrue<3.0.0,>=2.10.0->supabase)
#   Using cached h2-4.1.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.10->gotrue<3.0.0,>=2.10.0->supabase)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.1 (from pydantic<3,>=1.10->gotrue<3.0.0,>=2.10.0->supabase)
#   Downloading pydantic_core-2.27.1-cp312-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: six>=1.5 in c:\users\valen\desktop\job-website\.venv\lib\site-packages (from python-dateutil<3.0.0,>=2.8.1->realtime<3.0.0,>=2.0.0->supabase) (1.16.0)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[http2]<0.28,>=0.26->gotrue<3.0.0,>=2.10.0->supabase)
#   Using cached hyperframe-6.0.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[http2]<0.28,>=0.26->gotrue<3.0.0,>=2.10.0->supabase)
#   Using cached hpack-4.0.0-py3-none-any.whl.metadata (2.5 kB)
# Using cached supabase-2.10.0-py3-none-any.whl (16 kB)
# Downloading gotrue-2.11.0-py3-none-any.whl (48 kB)
# Using cached httpx-0.27.2-py3-none-any.whl (76 kB)
# Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
# Using cached postgrest-0.18.0-py3-none-any.whl (21 kB)
# Using cached realtime-2.0.6-py3-none-any.whl (20 kB)
# Using cached storage3-0.9.0-py3-none-any.whl (16 kB)
# Using cached supafunc-0.7.0-py3-none-any.whl (6.9 kB)
# Downloading aiohttp-3.11.8-cp312-cp312-win_amd64.whl (437 kB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading pydantic-2.10.2-py3-none-any.whl (456 kB)
# Downloading pydantic_core-2.27.1-cp312-none-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 275.1 kB/s eta 0:00:06
#    ---------- ----------------------------- 0.5/2.0 MB 275.1 kB/s eta 0:00:06
#    ---------- ----------------------------- 0.5/2.0 MB 275.1 kB/s eta 0:00:06
#    ---------- ----------------------------- 0.5/2.0 MB 275.1 kB/s eta 0:00:06
#    --------------- ------------------------ 0.8/2.0 MB 275.1 kB/s eta 0:00:05
#    --------------- ------------------------ 0.8/2.0 MB 275.1 kB/s eta 0:00:05
#    --------------- ------------------------ 0.8/2.0 MB 275.1 kB/s eta 0:00:05
#    --------------- ------------------------ 0.8/2.0 MB 275.1 kB/s eta 0:00:05
#    --------------------- ------------------ 1.0/2.0 MB 287.6 kB/s eta 0:00:04
#    --------------------- ------------------ 1.0/2.0 MB 287.6 kB/s eta 0:00:04
#    --------------------- ------------------ 1.0/2.0 MB 287.6 kB/s eta 0:00:04
#    --------------------- ------------------ 1.0/2.0 MB 287.6 kB/s eta 0:00:04
#    -------------------------- ------------- 1.3/2.0 MB 301.0 kB/s eta 0:00:03
#    -------------------------- ------------- 1.3/2.0 MB 301.0 kB/s eta 0:00:03
#    ------------------------------- -------- 1.6/2.0 MB 330.3 kB/s eta 0:00:02
#    ------------------------------- -------- 1.6/2.0 MB 330.3 kB/s eta 0:00:02
#    ------------------------------- -------- 1.6/2.0 MB 330.3 kB/s eta 0:00:02
#    ------------------------------------ --- 1.8/2.0 MB 339.0 kB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 357.3 kB/s eta 0:00:00
# Using cached websockets-13.1-cp312-cp312-win_amd64.whl (159 kB)
# Using cached anyio-4.6.2.post1-py3-none-any.whl (90 kB)
# Using cached aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached frozenlist-1.5.0-cp312-cp312-win_amd64.whl (51 kB)
# Using cached h2-4.1.0-py3-none-any.whl (57 kB)
# Using cached multidict-6.1.0-cp312-cp312-win_amd64.whl (28 kB)
# Using cached propcache-0.2.0-cp312-cp312-win_amd64.whl (44 kB)
# Downloading yarl-1.18.0-cp312-cp312-win_amd64.whl (90 kB)
# Using cached hpack-4.0.0-py3-none-any.whl (32 kB)
# Using cached hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Installing collected packages: websockets, pydantic-core, propcache, multidict, hyperframe, httpcore, hpack, frozenlist, deprecation, anyio, annotated-types, aiohappyeyeballs, yarl, pydantic, httpx, h2, aiosignal, aiohttp, supafunc, storage3, realtime, postgrest, gotrue, supabase
# Successfully installed aiohappyeyeballs-2.4.3 aiohttp-3.11.8 aiosignal-1.3.1 annotated-types-0.7.0 anyio-4.6.2.post1 deprecation-2.1.0 frozenlist-1.5.0 gotrue-2.11.0 h2-4.1.0 hpack-4.0.0 httpcore-1.0.7 httpx-0.27.2 hyperframe-6.0.1 multidict-6.1.0 postgrest-0.18.0 propcache-0.2.0 pydantic-2.10.2 pydantic-core-2.27.1 realtime-2.0.6 storage3-0.9.0 supabase-2.10.0 supafunc-0.7.0 websockets-13.1 yarl-1.18.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from supabase import create_client, Client
import os

# Supabase credentials
url = "https://qfwipzqywzjqoxzvrlxt.supabase.co"  # Replace with your Supabase URL
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InFmd2lwenF5d3pqcW94enZybHh0Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3MjAyNzQ1NzksImV4cCI6MjAzNTg1MDU3OX0.067C1RDQsklIyPs8Hr8eH5N-pu5jJ2pqV4wTZkcrbkM"  # Replace with your Supabase key

# Initialize Supabase client
supabase: Client = create_client(url, key)

# Path to CSV file
csv_file_path = r'C:\Users\valen\Desktop\JOB-WEBSITE\output.csv'  # Replace with your CSV file path

# Check if the file exists
if not os.path.isfile(csv_file_path):
    print(f"Error: The file '{csv_file_path}' does not exist.")
else:
    try:
        # Read CSV file
        df = pd.read_csv(csv_file_path)

        # Check if the DataFrame is empty
        if df.empty:
            print("Error: The CSV file is empty.")
        else:
            # Ensure the DataFrame column names match the Supabase table
            df.columns = ['POSITION', 'COMPANY NAME', 'LOCATION', 'SALARY', 'JOB LINK', 'BENEFITS', 'DESCRIPTION', 'EMPLOYMENT TYPE']

            # Convert all DataFrame values to strings and handle NaN
            df = df.astype(str).replace('nan', '')

            # Print the first few rows and column names for debugging
            print("DataFrame columns:", df.columns)
            print("First few rows of the DataFrame:")
            print(df.head())

            # Table name in Supabase
            table_name = 'Job_listing'

            # Convert DataFrame to dictionary and insert into Supabase
            records = df.to_dict(orient='records')

            try:
                # Perform insert operation
                response = supabase.table(table_name).insert(records).execute()
                print("Insert response:", response.data)
            except Exception as e:
                print("Error inserting records:", e)
    except pd.errors.EmptyDataError:
        print("Error: The CSV file is empty or cannot be read.")
    except Exception as e:
        print("Error reading the CSV file:", e)
# Out:
# DataFrame columns: Index(['POSITION', 'COMPANY NAME', 'LOCATION', 'SALARY', 'JOB LINK',
#        'BENEFITS', 'DESCRIPTION', 'EMPLOYMENT TYPE'],
#       dtype='object')
# First few rows of the DataFrame:
#                                     POSITION            COMPANY NAME LOCATION  \
# 0                                 Data Entry  Firstsource Healthcare   Remote
# 1  Entry Level – Wealth Management Associate      Equitable Advisors   Remote
# 2                               Data Analyst               Ascension   Remote
# 3                           Data Engineer II        Personify Health   Remote
# 4             Service Desk Analyst - Level 1            Wynne System   Remote
#
#                      SALARY  \
# 0
# 1
# 2
# 3  $92,352 - $95,000 a year
# 4  $40,000 - $50,000 a year
#
#                                             JOB LINK  \
# 0  https://careers.firstsource.com/job/Remote-Dat...
# 1  https://equitable.taleo.net/careersection/eqh_...
# 2  https://jobs.ascension.org/us/en/job/AHEAHUUS3...
# 3  https://careers-personifyhealth.icims.com/jobs...
# 4  https://volarisgroup.wd3.myworkdayjobs.com/en-...
#
#                                             BENEFITS  \
# 0                                 No benefits found.
# 1  ['401(k) matching', 'Dental insurance', 'Disab...
# 2  ['Adoption assistance', 'Disability insurance'...
# 3                                 No benefits found.
# 4                                 No benefits found.
#
#                                          DESCRIPTION EMPLOYMENT TYPE
# 0  Date: Nov 22, 2024\n      \n\n\n\n\n\n\n\n    ...
# 1  Entry Level – Wealth Management Associate - NJ...
# 2  Details \n\nDepartment: Network Services\n Sch...       Full-time
# 3  Overview: \n \n Now is the time to join us!\n\...    -  Full-time
# 4  Build Your Career and Future at Wynne.\n \n\n\...    -  Full-time
# Insert response: [{'POSITION': 'Data Entry', 'COMPANY NAME': 'Firstsource Healthcare', 'LOCATION': 'Remote', 'SALARY': '', 'JOB LINK': 'https://careers.firstsource.com/job/Remote-Data-Entry-Remo/32170044/?src=Indeed', 'BENEFITS': 'No benefits found.', 'DESCRIPTION': 'Date: Nov 22, 2024\n      \n\n\n\n\n\n\n\n       Location: Remote, Remote, US\n      \n\n\n\n\n\n\n\n       Requisition ID: 12835\n      \n\n\n\n\n\n\n\n       Description: \n       The Data Entry Operator is an entry level position which is production oriented. Individuals are responsible for the introduction of data into the system which is then provided to the client for use in their internal adjudication system.\n\nFOUNDATION KNOWLEDGE, SKILLS, AND/OR ABILITIES REQUIRED\nTo perform this job successfully, an individual must be able to perform each essential duty satisfactorily. The requirements listed below are representative of the knowledge, skill, and/or ability required. Reasonable accommodations may be made to enable individuals with disabilities to perform the essential functions\nESSENTIAL DUTIES AND RESPONSIBLITIES •\nEnter data from scanned and/or processed images into the data capture system.\nMeet expected hourly production volume goals.\nMaintain quality levels above minimums set by management\nIncrease speed and difficulty of tasks as expected with training and practice\n\nADDITIONAL RESPONSIBILITIES\n\nMaintain awareness of and actively participate in the Corporate Compliance Program.\n\n\nMaintain a neat and orderly workstation.\n\n\nAssist with other projects as assigned by management\n\n\nMust be prompt and dependable (excellent attendance)\n\n\nMust be comfortable working in a production environment\n\n\nProficient typing skills are required (35wpm / 98% accuracy min) (test required).\n\n\nPossess excellent organization skills\n\n\nReliability of task completion and follow-up\n\nQualifications - External\nEDUCATION/PREVIOUS EXPERIENCE\nHigh School diploma or equivalent\nExcellent Data Entry Skills\nComputer Knowledge\nBasic Math Skill', 'EMPLOYMENT TYPE': '', 'id': '1078ccaf-488f-4fb7-8667-fa1d48fbe749'}, {'POSITION': 'Entry Level – Wealth Management Associate', 'COMPANY NAME': 'Equitable Advisors', 'LOCATION': 'Remote', 'SALARY': '', 'JOB LINK': 'https://equitable.taleo.net/careersection/eqh_1/jobdetail.ftl?job=21000104&tz=GMT-06%3A00&tzname=America%2FChicago', 'BENEFITS': "['401(k) matching', 'Dental insurance', 'Disability insurance', 'Employee stock purchase plan', 'Health insurance', 'Life insurance', 'Vision insurance']", 'DESCRIPTION': 'Entry Level – Wealth Management Associate - NJ, Secaucus (4045) (21000104)\n \n\n Primary Location : UNITED STATES-Remote\n \n\n Organization : Equitable Advisors\n \n\n Description\n\n Equitable Advisors is a respected wealth management firm with a proven track record in the industry. We are driven by our mission to help our clients secure their financial well-being providing them confidence to pursue long and fulfilling lives. We have a passion to make a positive impact on the futures of individuals and businesses by offering financial services and products that address their evolving financial needs throughout their lifetime.\n Our people\nOur Financial Professionals come from a variety of backgrounds including recent college grads, career crossovers and experienced financial professionals, yet they all share several key traits: demonstrated patterns of success, values driven, entrepreneurial mindset, knack for networking and possess a desire to shape and protect their future as well as those they serve.\n\nWe value and respect people of all backgrounds and focus on developing diverse talent and fostering an inclusive work environment\n\n\nOur Diversity, Equity, and Inclusion (DEI) initiatives thrive from opportunities to participate in activities such as employee resource groups to our much-anticipated celebration of cultures and accomplishments at the annual Diversity Summit\n\n\nSocial impact and c ...

# %%
import pyttsx3

# Initialize the text-to-speech engine
engine = pyttsx3.init()

# List available voices
voices = engine.getProperty('voices')

# Print available voices to choose from
for voice in voices:
    print(f"ID: {voice.id}, Name: {voice.name}, Lang: {voice.languages}")

# Set properties for a clearer and dramatic effect
engine.setProperty('rate', 150)  # Speed percent (can go over 100)
engine.setProperty('volume', 1.0)  # Volume (0.0 to 1.0)

# Select a voice (change 'english-us' to another ID from your list if needed)
selected_voice_id = 'english-us'  # Use a suitable voice ID from your list
for voice in voices:
    if voice.id == selected_voice_id:
        engine.setProperty('voice', voice.id)
        break

# Speak the text

engine.say("NAHIDA TELL VALENTINE THE CODE HAS FINISHED SUCCESSFULLY   PLEASE NAHIDA TELL VALENTINE THE CODE HAS FINISHED ")

# Wait for the speech to complete
engine.runAndWait()
# Out:
# ID: HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-GB_HAZEL_11.0, Name: Microsoft Hazel Desktop - English (Great Britain), Lang: []
# ID: HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-US_ZIRA_11.0, Name: Microsoft Zira Desktop - English (United States), Lang: []
